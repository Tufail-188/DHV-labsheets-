# %%
# importing necesssory dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# ignoring the unnecessory warnings
import warnings
warnings.filterwarnings(action="ignore")

# %%
# importing the dataframe
df = pd.read_csv("/content/Meteorite_Landings.csv")

# %%
# Aceessing the first five column
df["name"].head()
# Out:
# 0      Aachen
# 1      Aarhus
# 2        Abee
# 3    Acapulco
# 4     Achiras
# Name: name, dtype: object

# %%
# pritning the columns of the dataframe
df.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
# lets check the missing values of the dataframe
df.isna().sum()
# Out:
# name              0
# id                0
# nametype          0
# recclass          0
# mass (g)        131
# fall              0
# year            291
# reclat         7315
# reclong        7315
# GeoLocation    7315
# dtype: int64

# %%
# datatypes of the features columns
df.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year            object
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
# description of the table
df.describe(include="all").transpose()
# Out:
#                count unique                     top   freq          mean  \
# name           45716  45716                  Aachen      1           NaN
# id           45716.0    NaN                     NaN    NaN  26889.735104
# nametype       45716      2                   Valid  45641           NaN
# recclass       45716    466                      L6   8285           NaN
# mass (g)     45585.0    NaN                     NaN    NaN  13278.078549
# fall           45716      2                   Found  44609           NaN
# year           45425    266  01/01/2003 12:00:00 AM   3323           NaN
# reclat       38401.0    NaN                     NaN    NaN     -39.12258
# reclong      38401.0    NaN                     NaN    NaN     61.074319
# GeoLocation    38401  17100              (0.0, 0.0)   6214           NaN
#
#                       std        min       25%       50%        75%  \
# name                  NaN        NaN       NaN       NaN        NaN
# ...

# %%
# Lets check wheather the id column in this constant or not
df.shape
# Out:
# (45716, 10)

# %%
# Frequency of the name type in the dataframe
df["nametype"].value_counts()
# Out:
# Valid     45641
# Relict       75
# Name: nametype, dtype: int64

# %%
result = df.query("`mass (g)` >= 100 and fall == 'Fell'")

# %%
result.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
# 5  Adhi Kot  379    Valid          EH4    4239.0  Fell
#
#                      year    reclat    reclong           GeoLocation
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)
# 5  01/01/1919 12:00:00 AM  32.10000   71.80000          (32.1, 71.8)

# %%
import requests
response = requests.get('https://data.nasa.gov/resource/gh4g-9sfh.json', params={"$limit":500_00})

if response.ok:
  payload = response.json()
else:
  print(f"request was not sucessful and returned code: {response.status_code}")
  payload = None

# %%
# importing the dataframe
df = pd.DataFrame(payload)

# %%
df.head()
# Out:
#        name   id nametype     recclass    mass  fall                     year  \
# 0    Aachen    1    Valid           L5      21  Fell  1880-01-01T00:00:00.000
# 1    Aarhus    2    Valid           H6     720  Fell  1951-01-01T00:00:00.000
# 2      Abee    6    Valid          EH4  107000  Fell  1952-01-01T00:00:00.000
# 3  Acapulco   10    Valid  Acapulcoite    1914  Fell  1976-01-01T00:00:00.000
# 4   Achiras  370    Valid           L6     780  Fell  1902-01-01T00:00:00.000
#
#        reclat      reclong                                        geolocation  \
# 0   50.775000     6.083330     {'latitude': '50.775', 'longitude': '6.08333'}
# 1   56.183330    10.233330  {'latitude': '56.18333', 'longitude': '10.23333'}
# 2   54.216670  -113.000000    {'latitude': '54.21667', 'longitude': '-113.0'}
# 3   16.883330   -99.900000     {'latitude': '16.88333', 'longitude': '-99.9'}
# 4  -33.166670   -64.950000   {'latitude': '-33.16667', 'longitude': '-64.95'}
#
# ...

# %%
df.shape
# Out:
# (45716, 12)

# %%
df.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass', 'fall', 'year', 'reclat',
#        'reclong', 'geolocation', ':@computed_region_cbhk_fwbd',
#        ':@computed_region_nnqa_25f4'],
#       dtype='object')

# %%
df.dtypes
# Out:
# name                           object
# id                             object
# nametype                       object
# recclass                       object
# mass                           object
# fall                           object
# year                           object
# reclat                         object
# reclong                        object
# geolocation                    object
# :@computed_region_cbhk_fwbd    object
# :@computed_region_nnqa_25f4    object
# dtype: object

# %%
df.tail(n = 1)
# Out:
#              name     id nametype recclass mass   fall  \
# 45715  Zulu Queen  30414    Valid     L3.7  200  Found
#
#                           year     reclat      reclong  \
# 45715  1976-01-01T00:00:00.000  33.983330  -115.683330
#
#                                              geolocation  \
# 45715  {'latitude': '33.98333', 'longitude': '-115.68...
#
#       :@computed_region_cbhk_fwbd :@computed_region_nnqa_25f4
# 45715                           8                        1177

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         45716 non-null  object
#  1   id                           45716 non-null  object
#  2   nametype                     45716 non-null  object
#  3   recclass                     45716 non-null  object
#  4   mass                         45585 non-null  object
#  5   fall                         45716 non-null  object
#  6   year                         45425 non-null  object
#  7   reclat                       38401 non-null  object
#  8   reclong                      38401 non-null  object
#  9   geolocation                  38401 non-null  object
#  10  :@computed_region_cbhk_fwbd  1659 non-null   object
#  11  :@computed_region_nnqa_25f4  1659 non-null   object
# dtypes: object(12)
# memory usage: 4.2+ MB

# %%
df.iloc[100:104,[0,3,4,5]]
# Out:
#               name       recclass   mass  fall
# 100         Benton            LL6   2840  Fell
# 101         Berduc             L6    270  Fell
# 102         Béréba  Eucrite-mmict  18000  Fell
# 103  Berlanguillas             L6   1440  Fell

# %%
df.dtypes
# Out:
# name                           object
# id                             object
# nametype                       object
# recclass                       object
# mass                           object
# fall                           object
# year                           object
# reclat                         object
# reclong                        object
# geolocation                    object
# :@computed_region_cbhk_fwbd    object
# :@computed_region_nnqa_25f4    object
# dtype: object

# %%
df["fall"] == "Fall"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45711    False
# 45712    False
# 45713    False
# 45714    False
# 45715    False
# Name: fall, Length: 45716, dtype: bool

# %%
df.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)

# %%
df.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass', 'fall', 'year', 'reclat',
#        'reclong', 'geolocation', ':@computed_region_cbhk_fwbd',
#        ':@computed_region_nnqa_25f4'],
#       dtype='object')

# %%
df["mass"].median()
# Out:
# 32.6

# %%
df['mass (g)'].max()
# Out:
# 60000000.0

# %%
df["mass (g)"].nunique()
# Out:
# 12576

# %%
df.recclass.unique()[:14]
# Out:
# array(['L5', 'H6', 'EH4', 'Acapulcoite', 'L6', 'LL3-6', 'H5', 'L',
#        'Diogenite-pm', 'Unknown', 'H4', 'H', 'Iron, IVA', 'CR2-an'],
#       dtype=object)
